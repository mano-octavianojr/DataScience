# %% [markdown]
# # Question #1 (15 minutes)

# %% [markdown]
# Create a program that find the sum of even numbers in a list.
#
#
# For example:
#
#      numList = [1,2,3,4] # sum: 6
#      numList2 = [2,3,4,2,1] # sum: 8
#
# Hint:
#   1. Create a loop to iterate all the elements in the list.
#   2. Check EACH element if it is ODD or EVEN.

# %%
### DO NOT CHANGE THIS CODE ###
numList = [4,2,5,2,5]
sumValue = 0
###############################

### CODE HERE ###
for x in numList:
  if x %2 == 0:   # Identify the even number
    sumValue += x # sumValue = sumValue + x
#################

print('sum: ', sumValue)
# Out:
# sum:  8

# %% [markdown]
# # Question #2 (15 minutes)

# %% [markdown]
#  Create a program that prints the longest/shortest word in a list.
#
#  For example:
#
#       listValue = ["hafe", "asl", "hon", "ap"]
#       #Output: Longest: "hafe", Shortest: "ap"
#
# Hint:
#   1. Create a loop to iterate all the elements in the list.
#   2. Check the length of EACH element and compare this to initially defined longest/shortest word length.
#   3. If the length is greater/less than the initially defined length, update the value to the new length and record the word/s.
#
# NOTE: You may use 2 separate loops.

# %%
### DO NOT CHANGE THIS CODE ###
nameList = ["hafe", "asl", "hon", "ap"]

shortest_length = 10000
shortest_word = None

longest_length = 0
longest_word = None
###############################

### CODE HERE ###

# LONGEST WORD
for name in nameList:
  if len(name) >= longest_length:
    longest_length = len(name)
    longest_word = name

# SHORTEST WORD
for name in nameList:
  if len(name) <= shortest_length:
    shortest_length = len(name)
    shortest_word = name
#################

print('Longest word:', longest_word, 'Shortest word:', shortest_word)
# Out:
# Longest word: hafe Shortest word: ap
