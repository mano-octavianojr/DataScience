# %% [markdown]
# # Question #1 (3 minutes)

# %% [markdown]
# Create a function that adds 4 numbers.
#
# Hint:
#
#      def func_name(param1, param2, ...):
#           # codes here

# %%
### CODE HERE ###

def add(a,b,c,d):
  sum = a + b + c + d
  # print(sum)
  return sum

#################

# %% [markdown]
# # Question #2 (3 minutes)

# %% [markdown]
# Create a function that returns the highest number from the 2 parameters passed.
#
# Hint:
#
#      def func_name(param1, param2):
#           # codes here

# %%
### CODE HERE ###

def add(a,b):
  if a > b:
    return a
  else:
    return b

#################
